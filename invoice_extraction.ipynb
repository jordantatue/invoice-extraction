# %% [markdown]
# <a href="https://colab.research.google.com/github/jordantatue/invoice-extraction/blob/master/invoice_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jordantatue/invoice-extraction.git

# %%
# !git config user.name "jordantatue"
# !git config user.email "tatuejordan@gmail.com"

# %%
# Installation de toutes les dépendences necessaires au projet
# !pip install pytesseract opencv-python pillow pdf2image
# !pip install transformers torch torchvision
# !pip install pandas numpy matplotlib seaborn
# !pip install fastapi uvicorn python-multipart pydantic
# !pip install requests

# !apt-get install -y tesseract-ocr
# !apt-get install -y tesseract-ocr-fra

# !apt-get install -y poppler-utils
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-fra is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.11).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# Vérification de l'installation des bibliothèque
import cv2
import pytesseract
from PIL import Image
import pdf2image
import torch
import transformers
import pandas as pd
import fastapi
import pydantic

print("OpenCV version:", cv2.__version__)
print("Tesseract version:", pytesseract.get_tesseract_version())
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Transformers version:", transformers.__version__)
print("FastAPI version:", fastapi.__version__)
# Out:
# OpenCV version: 4.12.0
# Tesseract version: 4.1.1
# PyTorch version: 2.8.0+cu126
# CUDA available: True
# Transformers version: 4.57.1
# FastAPI version: 0.120.1

# %%
import json
import pandas as pd
from pathlib import Path
# %cd invoice-extraction/
# Out:
# /content/invoice-extraction
